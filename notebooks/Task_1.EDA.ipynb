# %%
import sys


# Add the scripts and src directories to the Python path
scripts_dir = r'E:\DS+ML\AIM3\Week3\Week3\Week3.AIM3\scripts'
src_dir = r'E:\DS+ML\AIM3\Week3\Week3\Week3.AIM3\src'

if scripts_dir not in sys.path:
    sys.path.append(scripts_dir)

if src_dir not in sys.path:
    sys.path.append(src_dir)

# %%
# scripts/run_task_1.py
from data_loader import load_data, save_to_csv
from data_preprocessing import handle_missing_values, handle_outliers
from eda import data_summary, univariate_analysis, bivariate_analysis,descriptive_statistics, check_data_structure
from visualization import outlier_detection, trends_over_geography, visualize_eda

# %%
# Step 2: Handle missing values
txt_file_path = r"E:\DS+ML\AIM3\Week3\Data\MachineLearningRating_v3.txt"
csv_file_path = r"E:\DS+ML\AIM3\Week3\Data\MachineLearningRating_v3.csv"

# Step 1: Load and Convert Data
df = load_data(txt_file_path)
save_to_csv(df, csv_file_path)
# Out:
# File saved to E:\DS+ML\AIM3\Week3\Data\MachineLearningRating_v3.csv
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# ...

# %%
df = load_data(csv_file_path )
df = handle_missing_values(df, strategy='mean')

# Step 3: Handle outliers
df = handle_outliers(df, threshold=1.5)

# %%
# Descriptive Statistics
df = load_data(csv_file_path )
print("Descriptive Statistics:")
desc_stats = descriptive_statistics(df)
print(desc_stats)
# Out:
# Descriptive Statistics:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\ethio\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File c:\Users\ethio\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# ...

# %%
# Data Structure
print("\nData Structure:")
data_structure = check_data_structure(df)
print(f"Column Dtypes:\n{data_structure['column_dtypes']}")
print(f"Categorical Columns: {data_structure['categorical_columns']}")
print(f"Datetime Columns: {data_structure['datetime_columns']}")

# %%
# Step 4: Data Summary
data_summary(df)
